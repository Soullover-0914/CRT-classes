# %% [markdown]
# <a href="https://colab.research.google.com/github/Soullover-0914/CRT-classes/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
dt = pd.read_csv('/Iris.csv')

# %%
dt
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
dt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
dt['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
l = LabelEncoder()

# %%
dt['Species'] = l.fit_transform(dt['Species'])

# %%
dt['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
from sklearn.model_selection import train_test_split

# %%
x = dt.drop(['SepalLengthCm','Id','Species'],axis =1)
y = dt['Species']

# %%
x
# Out:
#      SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0             3.5            1.4           0.2
# 1             3.0            1.4           0.2
# 2             3.2            1.3           0.2
# 3             3.1            1.5           0.2
# 4             3.6            1.4           0.2
# ..            ...            ...           ...
# 145           3.0            5.2           2.3
# 146           2.5            5.0           1.9
# 147           3.0            5.2           2.0
# 148           3.4            5.4           2.3
# 149           3.0            5.1           1.8
#
# [150 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# x['SepalWidthCm'].plot(kind='hist', bins=20, title='SepalWidthCm')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: Species, Length: 150, dtype: int64

# %%
dt.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# Species        0.942830       0.782561     -0.419446       0.949043
#
#                PetalWidthCm   Species
# Id                 0.899759  0.942830
# SepalLengthCm      0.817954  0.782561
# SepalWidthCm      -0.356544 -0.419446
# PetalLengthCm      0.962757  0.949043
# PetalWidthCm       1.000000  0.956464
# Species            0.956464  1.000000

# %%
xtrain, xtest, ytrain, ytest = train_test_split(x,y, test_size=0.25)

# %%
ytest
# Out:
# 66     1
# 53     1
# 8      0
# 79     1
# 125    2
# 59     1
# 127    2
# 128    2
# 92     1
# 136    2
# 144    2
# 56     1
# 83     1
# 34     0
# 81     1
# 2      0
# 148    2
# 87     1
# 104    2
# 69     1
# 32     0
# 134    2
# 38     0
# 116    2
# 57     1
# 106    2
# 101    2
# 113    2
# 89     1
# 51     1
# 68     1
# 4      0
# 103    2
# 76     1
# 120    2
# 37     0
# 62     1
# 12     0
# Name: Species, dtype: int64

# %%
sns.pairplot(dt, hue='SepalLengthCm')

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
ypred = lr.predict(xtest)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(ytest,ypred)
# Out:
# 0.9473684210526315

# %%
import pickle

# %%
pickle.dump(lr,open('iris.pk1','wb'))
